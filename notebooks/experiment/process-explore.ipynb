# %% [markdown]
# # Process Data

# %%
import pandas as pd

# %% [markdown]
# ### Read Test Data

# %%
df_test = pd.read_pickle('..//data//raw//df_test.pkl')

# %%
df_test.head(1)
# Out:
#   newsdesk  section subsection material  \
# 0     OpEd  Opinion        NaN    Op-Ed
#
#                                    headline  \
# 0  Anyone Else Want to See Trump ‘Shut Up’?
#
#                                abstract  \
# 0  Our president as a terrible toddler.
#
#                                             keywords  word_count  \
# 0  ['Presidential Election of 2020', 'Biden, Jose...         925
#
#                     pub_date  is_popular  \
# 0  2020-10-01 00:05:51+00:00           1
#
#                                             uniqueID
# 0  nyt://article/e467c2ae-2df3-5836-a6ca-b23d0d33...

# %%
df_train = pd.read_pickle('..//data//raw//df_train.pkl')

# %%
# Large (takes about a minute on Ryzen Pro)
df_comments = pd.read_pickle('..//data//raw//df_comments.pkl')

# %%
# Not as large
df_articles = pd.read_pickle('..//data//raw//df_articles.pkl')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12792 entries, 0 to 12791
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   newsdesk    12792 non-null  object
#  1   section     12792 non-null  object
#  2   subsection  4267 non-null   object
#  3   material    12792 non-null  object
#  4   headline    12792 non-null  object
#  5   abstract    12789 non-null  object
#  6   keywords    12792 non-null  object
#  7   word_count  12792 non-null  int64
#  8   pub_date    12792 non-null  object
#  9   is_popular  12792 non-null  int64
#  10  n_comments  12792 non-null  int64
#  11  uniqueID    12792 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.2+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3995 entries, 0 to 3994
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   newsdesk    3995 non-null   object
#  1   section     3995 non-null   object
#  2   subsection  1426 non-null   object
#  3   material    3995 non-null   object
#  4   headline    3995 non-null   object
#  5   abstract    3995 non-null   object
#  6   keywords    3995 non-null   object
#  7   word_count  3995 non-null   int64
#  8   pub_date    3995 non-null   object
#  9   is_popular  3995 non-null   int64
#  10  uniqueID    3995 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 343.4+ KB

# %% [markdown]
# # Pull Article ID from one DataFrame and Select Comments from another

# %%
ID = df_articles.iloc[0]['uniqueID']

# %%
sample = df_comments[df_comments['articleID'] == ID]

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 185
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   commentID              186 non-null    int64
#  1   status                 186 non-null    object
#  2   commentSequence        186 non-null    int64
#  3   userID                 186 non-null    int64
#  4   userDisplayName        186 non-null    object
#  5   userLocation           186 non-null    object
#  6   userTitle              0 non-null      object
#  7   commentBody            186 non-null    object
#  8   createDate             186 non-null    object
#  9   updateDate             186 non-null    object
#  10  approveDate            186 non-null    object
#  11  recommendations        186 non-null    int64
#  12  replyCount             186 non-null    int64
#  13  editorsSelection       186 non-null    bool
# ...

# %%
abstract = df_articles[df_articles['uniqueID'] == ID].iloc[0]['abstract']
abstract
# Out:
# 'Congress could do much more to protect Americans who have served their country from predatory for-profit colleges.'

# %%
for text in sample['commentBody']:
    print(text)
# Out:
# Here is something I think is fraudulent that vets are subject to
#  If you use your VA home loan option you have to pay higher interest rates regardless of your credit rating becuase supposedly it is more risky.
# How exactly is a guaranteed loan more risky than a not guaranteed commercial loan?
# @magicisnotreal  I have used my VA loan option four times now and every time I not only get a great rate but the closing cost is less than a conventional loan and the fees are usually lower and I don’t need a down payment. Not sure what type of loan you are getting on your earth but on mine I’m really happy with it.
# @magi
#
# Why would someone take out a VA loan if a conventional loan had lower interest?  Because the VA loan does not require a 20% down payment.  If you add back the PMI requirement to a conventional mortgage with 3% down, the VA loan is cheaper even though the interest rate is higher.
# @JD
# ...
